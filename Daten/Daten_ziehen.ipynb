# %% [markdown]
# # Importe

# %%
import kagglehub
import os
import shutil

# %% [markdown]
# # Funktionen

# %%
def downlaoden(kaggle_pfad:str, ziel_pfad:str, dateiname:str) -> str:
    # Download latest version
    path = kagglehub.dataset_download(kaggle_pfad)
    
    # print("Path to dataset files:", path)
    
    # Set the path to the file you'd like to load
    file_path = f"{ziel_pfad}/{dateiname}.csv"
    
    # Finde die heruntergeladene Datei (z. B. eine .csv-Datei)
    for file in os.listdir(path):
        if file.endswith(".csv"):
            source_file = os.path.join(path, file)
            break
    else:
        return "Keine CSV-Datei im Kaggle-Download-Verzeichnis gefunden."
    
    # Erstelle Zielordner, falls noch nicht vorhanden
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    
    # Kopiere und benenne um
    shutil.copy(source_file, file_path)
    # print(f"Datei wurde kopiert nach: {file_path}")
    
    return "Gefunden"

# downlaoden("kaggle", "pfad", "datei")

# %% [markdown]
# # Ausführungen

# %%
downlaoden("mehmetisik/mushrooms", "mehmetisik", "mushrooms")
# Out:
# 'Gefunden'

# %%
downlaoden("wardabilal/student-stress-analysis", "students", "stress_analysis")
# Out:
# 'Gefunden'

# %%
downlaoden("mahmoudelhemaly/students-grading-dataset", "students", "grading_dataset") 
# https://www.kaggle.com/datasets/mahmoudelhemaly/students-grading-dataset?select=Students_Grading_Dataset_Biased.csv
# https://www.kaggle.com/datasets/mahmoudelhemaly/students-grading-dataset/data?select=Students+Performance+Dataset.csv
# Out:
# ...
# 100%|████████████████████████████████████████| 997k/997k [00:00<00:00, 1.65MB/s]
# Extracting files...
# 'Gefunden'

# %%
downlaoden("fedesoriano/heart-failure-prediction", "health", "heart_failure")
# Out:
# ...
# 100%|██████████████████████████████████████| 8.56k/8.56k [00:00<00:00, 11.9MB/s]
# Extracting files...
# 'Gefunden'

# %%
downlaoden("andrewmvd/heart-failure-clinical-data", "health", "Heart_Failure_Prediction")
# Out:
# ...
# 100%|██████████████████████████████████████| 3.97k/3.97k [00:00<00:00, 8.08MB/s]
# Extracting files...
# 'Gefunden'

# %%
downlaoden("fedesoriano/stroke-prediction-dataset", "health", "Stroke_Prediction") 
#https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset?select=healthcare-dataset-stroke-data.csv
# Out:
# ...
# 100%|███████████████████████████████████████| 67.4k/67.4k [00:00<00:00, 367kB/s]
# Extracting files...
# 'Gefunden'

# %%
downlaoden("utkarsh1093/crime-data-from-2020-to-nov2025", "Crimes", "LA_Crimes_2025")
# Out:
# ...
# 100%|██████████████████████████████████████| 37.0M/37.0M [00:01<00:00, 24.3MB/s]
# Extracting files...
# 'Keine CSV-Datei im Kaggle-Download-Verzeichnis gefunden.'

# %%
https://www.kaggle.com/datasets/rxnach/student-stress-factors-a-comprehensive-analysis

# %%
https://www.kaggle.com/datasets/poushal02/student-academic-stress-real-world-dataset

# %%
https://www.kaggle.com/datasets/wardabilal/student-stress-analysis

# %%
https://www.kaggle.com/datasets/tan5577/e-learning-ecosystem-dataset-2025?select=Coursera.csv
